# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# https://www.akshare.xyz/zh_CN/latest/introduction.html
import akshare as ak
import json
import pandas as pd
import rui_risk_kit as rrk

# %%
with open('assets.json','r') as myfile:
    data=myfile.read()

porfolio = json.loads(data)

open_mutual_fund_list = []
currency_mutual_fund_list = []

for open_fund in porfolio['open_fund_in_porfolio']:
    open_mutual_fund_list.append(open_fund)

for currency_fund in porfolio['currency_fund_in_portfolio']:
    currency_mutual_fund_list.append(currency_fund)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-f6ae27b26c88> in <module>
#       7 currency_mutual_fund_list = []
#       8
# ----> 9 for open_fund in porfolio['assets_in_porfolio']:
#      10     open_mutual_fund_list.append(open_fund)
#      11
#
# KeyError: 'assets_in_porfolio'

# %%
haha = rrk.get_currency_fund_values(curr)
print(haha)
# Out:
#              213009
# 净值日期
# 2021-06-25   0.5438
# 2021-06-24   0.5411
# 2021-06-23   0.7385
# 2021-06-22   0.5085
# 2021-06-21   0.5134
# ...             ...
# 2009-08-20   0.0664
# 2009-08-19   0.0598
# 2009-08-18  -0.0088
# 2009-08-17  -0.0565
# 2009-08-16   2.0927
#
# [3500 rows x 1 columns]
#             004972
# 净值日期
# 2021-06-27  0.7664
# 2021-06-26  0.7664
# 2021-06-25  0.7671
# 2021-06-24  0.7277
# 2021-06-23  0.7073
# ...            ...
# 2017-09-21  1.1401
# 2017-09-20  1.0018
# 2017-09-19  1.0123
# 2017-09-15  1.0125
# 2017-09-08  1.0113
#
# [1313 rows x 1 columns]
#              213009  004972
# 净值日期
# 2009-08-16   2.0927     NaN
# 2009-08-17  -0.0565     NaN
# 2009-08-18  -0.0088     NaN
# 2009-08-19   0.0598     NaN
# 2009-08-20   0.0664     NaN
# ...             ...     ...
# 2021-06-23   0.7385  0.7073
# 2021-06-24   0.5411  0.7277
# 2021-06-25   0.5438  0.7671
# 2021-06-26      NaN  0.7664
# 2021-06-27      NaN  0.7664
#
# [3701 rows x 2 columns]

# %%
my_mutual_fund_list = ['213009', '004342', '163406', '001714', '003095', '003096', '161725', '502056', '005918', '004972', '002963']
# my_mutual_fund_list = ['003095', '110011', '001714']
fund_em_info_df = rrk.get_mf_values(my_mutual_fund_list, indicator='累计净值走势')
fund_em_info_df.tail()
# Out:
# fail to retrieve data for  213009
# fail to retrieve data for  004972
#             004342  163406  001714  003095  003096  161725  502056  005918  \
# 净值日期
# 2021-06-21  2.2137  7.8981   3.795   4.223   4.173  3.1218  1.6537  1.4202
# 2021-06-22  2.2266  7.9422   3.800   4.317   4.266  3.1304  1.6924  1.4287
# 2021-06-23   2.237  8.0103   3.833   4.300   4.249  3.0790  1.6832  1.4357
# 2021-06-24  2.2408  8.0160   3.832   4.191   4.141  3.0916  1.6567  1.4383
# 2021-06-25  2.2749  8.0829   3.863   4.312   4.260  3.1216  1.7038  1.4616
#
#             002963
# 净值日期
# 2021-06-21  1.2675
# 2021-06-22  1.2710
# 2021-06-23  1.2721
# 2021-06-24  1.2672
# 2021-06-25  1.2680

# %%
btr = rrk.run_cppi(fund_em_info_df['2015':][my_mutual_fund_list].pct_change().dropna(), drawdown = 0.2)
ax = btr['Wealth'].plot(figsize=(16,9), legend=True)
btr['Risky Wealth'].plot(ax=ax, style='--', legend=True)
# Out:
# <AxesSubplot:xlabel='净值日期'>

# %%
rrk.summary_stats(btr['Wealth'].pct_change().dropna())
# Out:
#         Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# 003095           0.022138        0.031276 -0.260055  4.245981
# 110011           0.020653        0.025024 -0.282459  4.965836
# 001714           0.019930        0.025153 -0.324755  4.983303
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# 003095                 0.013406            0.019397     -0.244701
# 110011                 0.010428            0.014705     -0.363576
# 001714                 0.010631            0.015393     -0.389655
#
#         Max Drawdown
# 003095     -0.108550
# 110011     -0.091993
# 001714     -0.075677

# %%
rrk.summary_stats(btr['Risky Wealth'].pct_change().dropna())
# Out:
#         Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# 003095           0.014437        0.058319 -0.239721  4.287805
# 110011           0.013061        0.044874 -0.241194  5.112846
# 001714           0.012094        0.044975 -0.320532  5.138129
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# 003095                 0.027033            0.039009     -0.259794
# 110011                 0.020453            0.028738     -0.367429
# 001714                 0.020857            0.029735     -0.387533
#
#         Max Drawdown
# 003095     -0.374309
# 110011     -0.269118
# 001714     -0.204315
