# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# https://www.akshare.xyz/zh_CN/latest/introduction.html
import akshare as ak
import pandas as pd
import rui_risk_kit as rrk

# %%
fund_em_info_df = rrk.get_mf_values(['161725', '163406'], indicator='累计净值走势')
fund_em_info_df.tail()
# Out:
#             161725  163406
# 净值日期
# 2021-02-08  3.1397  8.4047
# 2021-02-09  3.1750  8.5636
# 2021-02-10  3.2509  8.6431
# 2021-02-18  3.1943  8.5625
# 2021-02-19  3.1852  8.5218

# %%
btr = rrk.run_cppi(fund_em_info_df['2020-02-09':][['161725', '163406']].pct_change().dropna(), drawdown = 0.2)
ax = btr['Wealth'].plot(figsize=(12,6), legend=True)
btr['Risky Wealth'].plot(ax=ax, style='--', legend=True)

# %%
rrk.summary_stats(btr['Wealth'].pct_change().dropna())
# Out:
#         Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# 161725           0.025160        0.020072 -0.425891  5.713451
# 163406           0.029838        0.028055 -0.721505  4.077427
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# 161725                 0.007786            0.010377     -0.234732
# 163406                 0.012212            0.018017     -0.005647
#
#         Max Drawdown
# 161725     -0.038416
# 163406     -0.073619

# %%
rrk.summary_stats(btr['Risky Wealth'].pct_change().dropna())
# Out:
#         Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# 161725           0.021175        0.034263 -0.403017  5.446852
# 163406           0.029222        0.049297 -0.717897  4.189217
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# 161725                 0.015053             0.01939     -0.250724
# 163406                 0.023276             0.03380     -0.015431
#
#         Max Drawdown
# 161725     -0.085454
# 163406     -0.161941
